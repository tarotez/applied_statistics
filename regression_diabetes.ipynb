# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import array as ar
import pandas as pd

df = pd.read_csv('Diabetes.csv')

# %%
target = df['Target']
BMI = df['BMI']
BP = df['BP']
cholesterol = df['Cholesterol']
LDL = df['LDL']

x1g, x2g, x3g, yg = BMI, BP, cholesterol, target
lr = 0.0001

def prediction(x1, a, b):
    return a * x1 + b

a, b = 0, 0
rs = []
cnt = 0
rmse = np.inf
for i in range(10):
    for x1, y in zip(x1g, yg):
        if cnt % 1 == 0:
            plt.scatter(x1g, yg, color='blue')
            plt.plot(x1g, prediction(x1g, a, b), color='red')
            plt.xlabel('bmi')
            plt.ylabel('target')
            plt.show()
        rmse_before = rmse
        rmse = np.sqrt(((yg - prediction(x1g, a, b)) ** 2).mean())
        rs.append(rmse)
        if rmse_before - rmse < 0.0001:
            break
        error = y - prediction(x1, a, b)
        a += lr * error * x1
        b += lr * error
        cnt += 1
plt.plot(rs)
plt.show()
